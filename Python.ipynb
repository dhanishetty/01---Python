# %% [markdown]
# # Chapter - 1

# %% [markdown]
# ### Operator Operation Example Evaluates to…
# * Exponent ** = 2 ** 3 8
# * Modulus/remainder % = 22 % 8 6
# * Integer division/floored quotient  // = 22 // 8 2
# * Division / = 22 / 8 2.75
# * Multiplication * = 3 * 5 15
# * Subtraction - = 5 - 2 3
# * Addition + = 2 + 2 4
#
# The ** operator is evaluated first and the *, /, //, and % operators are evaluated next, from left to right. The + and - operators are evaluated last
#
# ### Expressions compute and return a value based on the given operands and operators.
# * Arithmetic expression: 5 + 3 * 2
# * Boolean expression: x > 10 and y < 20
# * String expression: "Hello" + " World"

# %% [markdown]
# ### Augmented assignment Statement
#
# * spam = 36
# * spam += 1 -> spam = spam + 1
# * spam -= 1 -> spam = spam - 1
# * spam *= 1 -> spam = spam * 1
# * spam /= 1 -> spam = spam / 1
# * spam %= 1 -> spam = spam % 1

# %% [markdown]
# ### Strings
#
# * Strings are immutable. Have to create a new one
#
# >>> String Concatenation
#
# * 'Alice' + 'Bob' = 'AliceBob'
#
# >>> String Multiplication
# * 'Alice' * 5 = 'AliceAliceAliceAliceAlice'
#
#
# >>> String first and last letter
#
# <pre>
# name = "Pythogaraus"
#
# print(name[0]) -> P
# print(name[-1]) -> s
#
# print(name[0:2]) -> Py
# print(name[-2]) -> u
# </pre>
#
# >>> finding in strings
#
# <pre>
# name = "Pythogaraus"
#
# print("gar" in name) -> True
# print("lol" not in name) -> True
# print("lol" in name) -> False
# </pre>
#
# >>> Printing letters in string
#
# <pre>
# name = "Pythogaraus"
#
# for x in name:
#     print(x) ->
# P
# y
# t
# h
# o
# g
# a
# r
# a
# u
# s
# </pre>

# %% [markdown]
# ### Manipulating Strings
#
# - upper() and lower() return an uppercase or lowercase string.
# - isupper(), islower(), islapha(), isalnum(), isdecimal(), isspace(), istitle() returns
# True or False if the string is that respective kind of string.
# - startswith() and endswith() also return bools.
# -','.join(['cat', 'dog']) returns a string that combines the strings in a list.
# - 'Hello world'.split() returns a list of strings, split from the string it's called on.
# - rjust(), ljust(), center() returns a string padded with spaces.
# - strip(), rstrip(), Istrip() returns a string with whitespace stripped off the sides.
# - replace() will replace all occurences of the first string argument with the second
# string argument.
# - pyperclip has copy() and paste() functions for using the clipboard.
#
# >>> upper() and lower()
#
# <pre>
# spam = "Automate the Boring Stuff with Python !!!"
#
# spam.upper() -> 'AUTOMATE THE BORING STUFF WITH PYTHON !!!'
# spam.lower() -> 'automate the boring stuff with python !!!'
# </pre>
#
# >>> If Upper or not
#
# <pre>
# spam = "Automate the Boring Stuff with Python"
#
#
# spam.isupper() -> False
# spam.islower() -> False
# </pre>
# >>> isalpha() - letters only
#
# <pre>
# spam = "AUTOMATE !"
# text = "AUTOMATE"
#
# spam.isalpha() -> false
# spam.isalpha() -> true
#
#
# </pre>
#
#
# >>>isalnum() - letters and number only
# <pre>
# spam = "egg123"
#
# spam.isalnum() -> True
# </pre>
#
# >>>isdecimal()- numbers only.
#
# >>> isspace() - whitespace only
#
# >>> istitle() - titlecase only (All words starts with capital letters)
#
# >>> converting to title .title()
#
# <pre>
# spam = "automate the boring stuff with python !!!"
#
# spam.title() -> 'Automate The Boring Stuff With Python !!!'
# </pre>
#
# >>> startswith()
#
# <pre>
# spam = "automate the boring stuff with python !!!"
#
# spam.startswith("auto") -> True
# </pre>
# >>> endswith()
#
# <pre>
# spam = "automate the boring stuff with python !!!"
#
# spam.endswith("!!!") -> True
# </pre>
#
# >>> Join the list of strings
#
# <pre>
#
# cars = ['camry', 'accord', 'civic','sonata']
#
# All_cars = '||'.join(cars)
# print(All_cars) -> camry||accord||civic||sonata
# </pre>
#
# >>> # Split the strings into list
#
# <pre>
# text = "Lesson 20 - Python Programming (Automate the Boring Stuff with Python)"
#
# text_list = text.split()
# print(text_list) -> ['Lesson', '20', '-', 'Python', 'Programming', '(Automate', 'the', 'Boring', 'Stuff', 'with', 'Python)']
# </pre>
#
# <pre>
# cars = "camry||accord||civic||sonata"
# cars_list = cars.split('||')
# print(cars_list)
# </pre>
#
# >>> right justify and left justify. padding the strings
#
# <pre>
# x = "auto"
#
# x.rjust(10) -> '      auto'
# x.ljust(10) -> 'auto      '
# x.ljust(10, '*') -> 'auto******'
# x.center(10, '=')-> '===auto==='
#
# </pre>
#
# >>> Striping left, right and all around the word
#
# <pre>
# x = "   auto   "
#
# x.strip() -> 'auto'
# </pre>
#
# <pre>
# x = '===auto==='
# print(x.strip('=')) -> auto
# print(x.lstrip('=')) -> auto===
# print(x.rstrip('=')) -> ===auto
# </pre>
#
# *Strips letters not words
# <pre>
# x = 'catcatdogcatcat'
# print(x.strip('atc')) -> 'dog'
# </pre>
#
# >>> Replacing letters or words
#
# <pre>
# x = "She sells seashells by the seashore"
# print(x.replace("sea", "C")) -> She sells Cshells by the Cshore
# </pre>

# %%
x = "She sells seashells by the seashore"
print(x.replace("sea", "C"))
# Out:
# She sells Cshells by the Cshore

# %%
cars = "camry||accord||civic||sonata"
cars_list = cars.split('||')
print(cars_list)
# Out:
# ['camry', 'accord', 'civic', 'sonata']

# %% [markdown]
# ### Assignment Statements
# * spam = 40
# * eggs = 2
# * spam + eggs = 42
#
# You could treat the variables as numbers as they are assigned integeres or floats

# %% [markdown]
# ### Variable Names
#
# 1. It can be only one word.
# 2. It can use only letters, numbers, and the underscore (_) character.
# 3. It can’t begin with a number.
#
# >>> Assigning Multiple Variables
#
# <pre>
# size, tail, disposition = 'Skinny', 'long', 'quiet'
# </pre>
#
# >>> Variables swapping
#
# <pre>
# a = 'AAA'
# b = 'BBB'
# a,b = b,a
# print(a) -> BBB
# print(b) -> AAA
# </pre>

# %% [markdown]
# ### Converting data types
#
# * int(7.77) = 7
# * float(7) = 7.0
# * str(7) = '7'
#
# ### None data type is Nonetype
#
# * print function returns None type
# * Any functions which does not have return statement returns None
#
# <pre>
# spam = print()
# print(spam == None) -> None
# </pre>

# %% [markdown]
# # Chapter-2 Flow Control

# %% [markdown]
# ### Boolean Values
# * True
# * False
#
# ### Boolean Operators
#
# * and
# * or
# * not
#
# ### Comparison Operators
#
# 1. '== Equal to
# 2. '!= Not equal to
# 3. '< Less than
# 4. '> Greater than
# 5. '<= Less than or equal to
# 6. '>= Greater than or equal to

# %% [markdown]
# ## Flow Control Statements

# %% [markdown]
# ### If-elif
#
# <pre>
# if name == 'Alice':<br>
#     print('Hi, Alice.')<br>
# elif age < 12:<br>
#     print('You are not Alice, kiddo.')<br>
# else:<br>
#     print('You are neither Alice nor a little kid.')<br>
#
# </pre>

# %% [markdown]
# ### While Loop - execute block of code over and over again - executes code as long as condition is True
#
# <pre>
# name = ''
# while name != 'your name':
#     print('Please type your name.')
#     name = input()
# print('Thank you!')
# </pre>
#
# * The code runs till you enter 'your name'

# %% [markdown]
# ### break Statements - it helps getting the program execution to break out of a while loop’s clause early.
# * The first line creates infinite loops (while True:)
#
# <pre>
# while True:
#     print('Please type your name.')
#     name = input()
#     if name == 'your name':
#         break
# print('Thank you!')
# </pre>

# %% [markdown]
# ### continue Statements - It skips back to start of the loop
#
# <pre>
# while True:
#     print('Who are you?')
#     name = input()
#     if name != 'Joe':
#         continue
#     print('Hello, Joe. What is the password? (It is a fish.)')
#     password = input()
#     if password == 'swordfish':
#         break
# print('Access granted.')
# </pre>

# %% [markdown]
# ### falsey Values
#
# * When used in conditions, 0, 0.0, and '' (the empty string) are considered False, while all other values are considered True.
#
# <pre>
# name = ''
# while not name:
#     print('Enter your name:')
#     name = input()
# print('How many guests will you have?')
# numOfGuests = int(input())
# if numOfGuests:
#     print('Be sure to have enough room for all your guests.')
# print('Done')
# </pre>

# %% [markdown]
# ### For loop - could use 'break' and 'continue' statements as well
#
# >>> For Loop with Range function
# * for i in range(5):
#
# ### The Starting, Stopping, and Stepping Arguments to range()
#
# * the below output is 12,13,14,15
# <pre>
# for i in range(12, 16):
#     print(i)
# </pre>
#
# <pre>
# for i in range(0, 10, 2):
#     print(i)
# </pre>
#
# <pre>
# for i in range(5, -1, -1):
#     print(i)
# </pre>

# %% [markdown]
# ### To get a random number for loops
#
# * import random
# * print(random.randint(1, 18))

# %% [markdown]
# ### round() if there is 0.5 it gives closest even number and abs() - just removes negative
#
# * print(round(3.14159, 2)) -> 3.14
# * print(round(3.14159)) -> 3
# * print(round(2.5)) -> 2
# * print(round(3.5)) -> 4
# * print(abs(-9.55)) -> 9.55

# %% [markdown]
# ### sys.exit() - used to terminate the program.
#
# <pre>
# import sys
#
# while True:
#     print('Type exit to exit.')
#     response = input()
#     if response == 'exit':
#         sys.exit()
#     print('You typed ' + response + '.')
# </pre>

# %% [markdown]
# ### The None value
#
# * 'None' represents the absence of a value.
# *  None is the only value of the NoneType data type.
# *  spam = print('Hello!') -> Hello!
# *  None == spam -> True

# %% [markdown]
# ### Print Functions end & sep
#
# * print ("Hello", end = "")
# * print ("World")
#
# > will print two words in one line  -> Hello World
#
# * print ("cat", "dog", "pig" , sep = " || " ) -> cat || dog || pig

# %% [markdown]
# ### Local Variables & Global variables
#
# * You could declare Global variables from functions
# <pre>
# def spam():
#     global eggs
#     eggs = 'spam'
# eggs = 'global'
# spam()
# print(eggs)
# </pre>
#
# >>> Output will be "spam" as the function was called in the last

# %% [markdown]
# ### Exception Handling - program to detect errors, handle them, and then continue to run.
#
# * use `try:` when the 'try:' fails use `except`
# * The `raise` keyword is used to trigger an exception intentionally.
# * we could handle different errors different ways
#
#
# <pre>
# def spam(divideBy):
#     try:
#         return 42 / divideBy
#     except ZeroDivisionError:
#         print('Error: You tried to divide by 0')
#     except:
#         print('unknown error')
# </pre>
#
# * Given Inputs
#
# <pre>
# print(spam(2)) -> 21.0
# print(spam(12)) -> 3.5
# print(spam(0)) -> Error: You tried to divide by 0
# print(spam(1)) -> 42.0
# print(spam('hello')) -> unknown error
# </pre>
#
# >>> `raise` - Intentional exception
#
# * When `raise` is executed, it stops the current function's execution and passes the exception up to the calling code. If not caught by a try-except block, it will eventually terminate the program.
# * You can `raise` built-in exceptions (like `ValueError`, `TypeError`, etc.) or your own custom exceptions to indicate specific error conditions. For example:
#
# <pre>
# raise ValueError("Invalid input")
#
# </pre>

# %% [markdown]
# ## Lists
# * Lists are Mutable i.e.., items can be added, removed or changed
# * Lists values are not completely copied to a variable they are just referenced i.e., if a list is copied to another variable and the child variable is modified then parent variable list is also modified.
# * Can access the values using its index
# * Comma seperated values
# * Could have different data types in single list
#
# >>> Copying List to another variable
# <pre>
# import copy
#
# List_1 = ["A", "B", "C"]
# List_2 = copy.deepcopy(List_1)
# List_2.append("Dog")
# print(List_1, List_2) -> ['A', 'B', 'C'] ['A', 'B', 'C', 'Dog']
# </pre>
#
# >>> Accessing the list
# <pre>
# x= ['cat', 'dog', 'pig', 9]
#
# print(x[0]) -> cat
# print(x[-1]) -> 9
# print(x[0:2])  = print(x[:2]) -> ['cat', 'dog']
# print (x[1:]) -> ['dog', 'pig', 9]
#
# y= [['cat', 'dog', 'pig', 9], [0,1,2,3]]
#
# print(y[0]) -> ['cat', 'dog', 'pig', 9]
# print(y[0][2]) -> pig
# </pre>
#
# ### Assigning new value to the list
#
# <pre>
# x[0] = ['rat']
# x = ['rat', 'dog', 'pig', 9]
# </pre>
#
#  >>> assign multiple values
# <pre>
# x[0:2] = [3, 6]
#
# x -> [3, 6, 'pig', 9]
#
# </pre>
#
#  >>> Deleting values
# <pre>
# del x[0] -> [6, 'pig', 9]
#
# </pre>
#
# >>> counting list
#  <pre>
# len(x) -> 3
#
# </pre>
#
# >>> Modifying list
#  <pre>
# print(x*3) -> [6, 'pig', 9, 6, 'pig', 9, 6, 'pig', 9]
#
# </pre>
#
# >>> calling list function
#  <pre>
# list("hello") -> ['h', 'e', 'l', 'l', 'o']
#
# </pre>
#
# >>> To find if element is in list or not in the list
#
# <pre>
# 'howdy' in ['hi', 'howdy', 'hello', 'heyas'] -> True
# 'howdy' not in ['hi', 'howdy', 'hello', 'heyas'] -> False
#
# 'hey' in ['hi', 'howdy', 'hello', 'heyas'] -> False
# 'hey' not in ['hi', 'howdy', 'hello', 'heyas'] -> True
# </pre>

# %% [markdown]
# >>> for loops with lists
#
# <pre>
# x = [0,1,2,3,4]
# for i in x:
#     print(i) -> 0,1,2,3,4
# </pre>
# > for loop to find index
# <pre>
# Supplies = ["pens", "pencils", "erasers", "folders", "staplers"]
# for i in range(len(Supplies)):
#     print (f"There are {Supplies[i]} at index {i} Position")
# </pre>
# > for loop to find index of item
# <pre>
#
# Supplies = ["pens", "pencils", "erasers", "folders", "staplers","pens"]
#
# for x in range(len(Supplies)):
#     if Supplies[x] == "pens":
#         print (f"{Supplies[x]} is at index : {x}")
# print("Thank you")
# </pre>
#
#
# >>> Multiple Assignment
#
# <pre>
# x = list(range(0,10,2))
# print(x) -> [0, 2, 4, 6, 8]
# </pre>
# ---
#
# <pre>
# cat = ['fur', 'cute', 'active']
# texture, nature, mindset = cat
# print (texture, nature, mindset ) -> fur cute active
# </pre>
#
# ### or
#
# <pre>
# cat_status = cat[2]
# print(cat_status) -> active
# </pre>

# %% [markdown]
# ## List Methods
#
# >>> Index method . index('item') -> Provides the index of the item in the list
#
# * If you have multiple same items it returns the index of the first item
#
# <pre>
# spam = ['Hello', 'Hi', 'Heyas', 'Howdy']
# spam.index('Hi') -> 1
# </pre>
#
# >>> Append Method .append('item') -> Adds the item to the end of the list
#
# <pre>
# spam = ['Hello', 'Hi', 'Heyas', 'Howdy']
# spam.append('Holla')
# print(spam) -> ['Hello', 'Hi', 'Heyas', 'Howdy', 'Holla']
# </pre>
#
# >>> Insert Method .insert(3,'item') -> inserts item at the mentioned index position
#
# <pre>
# spam = ['Hello', 'Hi', 'Heyas', 'Howdy', 'Holla']
# spam.insert(1, 'Namaste')
# print(spam) -> ['Hello', 'Namaste', 'Hi', 'Heyas', 'Howdy', 'Holla']
# </pre>
#
# >>> Remove Method .Remove('item') -> remove item from the list (if same item is in multiple positions just first one)
#
# <pre>
# spam = ['Hello', 'Namaste', 'Hi', 'Heyas', 'Howdy', 'Holla']
# spam.remove('Heyas')
# print(spam) -> ['Hello', 'Namaste', 'Hi', 'Howdy', 'Holla']
# </pre>
#
# >>> sort Method .sort() -> Sorts the lists
#
# <pre>
# x = [5,3.6,1,8,9,4,-12,6]
# x.sort()
# print(x) -> [-12, 1, 3.6, 4, 5, 6, 8, 9]
# </pre>
# > Sorts but first comes capital and later small letters
# <pre>
# x = ['A','c','B','a','C','b']
# x.sort()
# print(x) -> ['A', 'B', 'C', 'a', 'b', 'c']
# </pre>
#
# > Sorts both capital and small letters
#
# <pre>
# x = ['A','c','B','a','C','b']
# x.sort(key= str.lower)
# print(x) -> ['A', 'a', 'B', 'b', 'c', 'C']
# </pre>
#
# >>> Reverse sort Method .sort() -> Sorts the lists
#
# <pre>
# x = [5,3.6,1,8,9,4,-12,6]
# x.sort(reverse=True)
# print(x) -> [9, 8, 6, 5, 4, 3.6, 1, -12]
# </pre>
#
# >>> Converting Tuples to List
#
# <pre>
# Final_list = ('pens', 'pencils', 'erasers', 'folders', 'staplers', 'pens')
#
# Supplies = list(Final_list)
# print(Supplies) -> ['pens', 'pencils', 'erasers', 'folders', 'staplers', 'pens']
# </pre>

# %% [markdown]
# ### Tuple datatype
# * Tuples are typed with parentheses, ( and ), instead of square brackets, [ and ].
# * Tuples, like strings, are immutable.
#
# >>> To have only one value in Tuple
# <pre>
# x = ('item',)
# print(type(x), x)
# </pre>
# Output =  <class 'tuple'> ('item',)
#
# >>> Converting List to Tuples
#
# <pre>
# Supplies = ["pens", "pencils", "erasers", "folders", "staplers","pens"]
# Final_list = tuple(Supplies)
# print(Final_list) -> ('pens', 'pencils', 'erasers', 'folders', 'staplers', 'pens')
#
# </pre>

# %% [markdown]
# ### Dictionaries
#
# - Dictionaries contain key-value pairs. Keys are like a list's indexes.
# - Dictionaries are mutable. Variables hold references to dictionary values, not the dictionary value itself.
# - Dictionaries are unordered. There is no "first" key-value pair in a dictionary.
# - The keys(), values(), and items() methods will return list-like values of a dictionary's keys, values, and both keys and values, respectively.
# - The get() method can return a default value if a key doesn't exist.
# - The setdefault() method can set a value if a key doesn't exist.
# - The pprint module's pprint() "pretty print" function can display a dictionary value cleanly. The pformat() function returns a string value of this output.
#
#
# >>> Adding a key-value pair
#
# <pre>
# Car = {'Make' : 'Toyota','Model' : 'Camry', 'Color':'Silver'}
#
# if 'drive' not in Car:
#     Car['drive'] = 'awd'
#
# Car -> {'Make': 'Toyota', 'Model': 'Camry', 'Color': 'Silver', 'drive': 'awd'}
# </pre>
#
#
# >>> Items are unordered, The order doesnt matter.
# <pre>
# Car = {'Make' : 'Toyota','Model' : 'Camry', 'Color':'Silver'}
#
# Car_1 = {'Color':'Silver', 'Make' : 'Toyota','Model' : 'Camry'}
#
# Car == Car_1 -> True
# </pre>
#
# >>> In & Not In
#
# <pre>
# Car = {'Make' : 'Toyota','Model' : 'Camry', 'Color':'Silver'}
#
# 'Model' in Car -> True
#
# 'Silver' in Car.values() -> True
#
#
# </pre>
#
# >>> keys() - Method
#
# <pre>
# Car = {'Make' : 'Toyota','Model' : 'Camry', 'Color':'Silver'}
#
# print(list(Car.keys())) -> ['Make', 'Model', 'Color']
# </pre>
#
# >>> values() - Method
#
# <pre>
# Car = {'Make' : 'Toyota','Model' : 'Camry', 'Color':'Silver'}
#
# print(list(Car.values())) -> ['Toyota', 'Camry', 'Silver']
# </pre>
# >>> items() - Method
#
# <pre>
# Car = {'Make' : 'Toyota','Model' : 'Camry', 'Color':'Silver'}
#
# print(list(Car.items()))
# </pre>
#
# >>> For with Methods
#
# <pre>
# for k in Car.keys():
#     print(k)
#
# for l in Car.values():
#     print(l)
#
# for k, v in Car.items():
#     print(k,v)
#
# for x in Car.items():
#     print(x)
# </pre>
#
# Output =
#
#   1. Make
# Model
# Color
# <br />
#
# 2. Toyota
# Camry
# Silver
# <br />
#
# 3. Make Toyota
# Model Camry
# Color Silver
# <br />
#
# 4. ('Make', 'Toyota')
# ('Model', 'Camry')
# ('Color', 'Silver')
#
# <br/>
#
# >>> get() - method
#
# * It doesnt throw any error even if the keys doesn't exist
#
# <pre>
# cars = {'Toyota' : 5, 'Honda' : 9, 'GMC' : 3, 'Ford' :12}
#
# print(cars.get('Ferrari', 0)) -> 0
#
# print(cars.get('Honda', 0)) -> 0
# </pre>
#
# >>> setdefault() - method, Checks before adding key- value pair
#
# <pre>
#
# cars = {'Toyota' : 5, 'Honda' : 9, 'GMC' : 3, 'Ford' :12}
#
# cars.setdefault('Nissan',9)
# print(cars) -> {'Toyota': 5, 'Honda': 9, 'GMC': 3, 'Ford': 12, 'Nissan': 9}
# </pre>
#
# > setdefault() used to count letters in text
# <pre>
# text = "Write a function that takes a list value as an argument and returns a string with all the items separated by a comma and a space, with and inserted before the last item. For example, passing the previous spam list to the function would return 'apples, bananas, tofu, and cats'. But your function should be able to work with any list value passed to it."
#
# count = {}
#
# for character in text.upper():
#     count.setdefault(character, 0)
#     count[character] = count[character] + 1
# print(count)
# </pre>
#
# output =
#
# {'W': 6, 'R': 14, 'I': 17, 'T': 33, 'E': 27, ' ': 64, 'A': 33, 'F': 6, 'U': 14, 'N': 20, 'C': 6, 'O': 15, 'H': 9, 'K': 2, 'S': 22, 'L': 13, 'V': 3, 'G': 3, 'M': 7, 'D': 9, 'P': 9, 'B': 6, 'Y': 3, ',': 5, '.': 3, 'X': 1, "'": 2}
#
# >>> pprint.pprint() Clean view of dictionary
#
# <pre>
# import pprint
#
# pprint.pprint(count)
# </pre>
#
# Output =
#
# {' ': 64, <br/>
#  "'": 2, <br/>
#  ',': 5, <br/>
#  '.': 3,<br/>
#  'A': 33,<br/>
#  'B': 6,<br/>
#  'C': 6,<br/>
#  'D': 9,<br/>
#  'E': 27,<br/>
#  'F': 6,<br/>
#  'G': 3,<br/>
#  'H': 9,<br/>
#  'I': 17,<br/>
#  'K': 2,<br/>
#  'L': 13,<br/>
#  'M': 7,<br/>
#  'N': 20,<br/>
#  'O': 15,<br/>
#  'P': 9,<br/>
#  'R': 14,<br/>
#  'S': 22,<br/>
#  'T': 33,<br/>
#  'U': 14,<br/>
#  'V': 3,<br/>
#  'W': 6,<br/>
#  'X': 1,<br/>
#  'Y': 3}
#
#  > pprint.pformat() assigning cleaned view to the variable
#
#  <pre>
# import pprint
#
# clean_x = pprint.pformat(count)
# print(clean_x)
# </pre>

# %%
text = "Write a function that takes a list value as an argument and returns a string with all the items separated by a comma and a space, with and inserted before the last item. For example, passing the previous spam list to the function would return 'apples, bananas, tofu, and cats'. But your function should be able to work with any list value passed to it."

count = {}
for character in text.upper():
    count.setdefault(character, 0)
    count[character] = count[character] + 1
print(count)
# Out:
# {'W': 6, 'R': 14, 'I': 17, 'T': 33, 'E': 27, ' ': 64, 'A': 33, 'F': 6, 'U': 14, 'N': 20, 'C': 6, 'O': 15, 'H': 9, 'K': 2, 'S': 22, 'L': 13, 'V': 3, 'G': 3, 'M': 7, 'D': 9, 'P': 9, 'B': 6, 'Y': 3, ',': 5, '.': 3, 'X': 1, "'": 2}

# %%
import pprint

pprint.pprint(count)
# Out:
# {' ': 64,
#  "'": 2,
#  ',': 5,
#  '.': 3,
#  'A': 33,
#  'B': 6,
#  'C': 6,
#  'D': 9,
#  'E': 27,
#  'F': 6,
#  'G': 3,
#  'H': 9,
#  'I': 17,
#  'K': 2,
#  'L': 13,
#  'M': 7,
#  'N': 20,
#  'O': 15,
#  'P': 9,
#  'R': 14,
#  'S': 22,
#  'T': 33,
#  'U': 14,
#  'V': 3,
#  'W': 6,
#  'X': 1,
#  'Y': 3}
